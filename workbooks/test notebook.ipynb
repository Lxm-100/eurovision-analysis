# %%
import pandas as pd

# %%
votes = pd.read_csv("./votes.csv")

# %%
votes.sort_values("year", ascending = False, inplace = True)
votes = votes[votes["round"]=="final"]
votes = votes[votes["from_country_id"]=="fr"]
votes = votes[~(votes['round'] == "semi")] 
votes = votes[~(votes['jury_points'] == 0.0)]

# %%
votes.head(50)
# Out:
#        year  round from_country_id to_country_id from_country to_country  \
# 45568  2019  final              fr            az           fr         az
# 45561  2019  final              fr            nl           fr         nl
# 45562  2019  final              fr            it           fr         it
# 45564  2019  final              fr            ch           fr         ch
# 45565  2019  final              fr            se           fr         se
# 45567  2019  final              fr            mk           fr         mk
# 45569  2019  final              fr            au           fr         au
# 45570  2019  final              fr            is           fr         is
# 45571  2019  final              fr            cz           fr         cz
# 45572  2019  final              fr            dk           fr         dk
# 43696  2018  final              fr            gb           fr         gb
# 43673  2018  final              fr            il           fr         il
# ...

# %%
df1 = pd.read_csv("./contestants.csv")

# %%
df1.head(20)
# Out:
#       year to_country_id      to_country                   performer  \
# 1436  2017            pt        Portugal             Salvador Sobral
# 1396  2016            ru          Russia              Sergey Lazarev
# 1437  2017            bg        Bulgaria             Kristian Kostov
# 1394  2016            ua         Ukraine                      Jamala
# 1478  2018            il          Israel              Netta Barzilai
# 1526  2019            no          Norway                      KEiiNO
# 1438  2017            md         Moldova           Sunstroke Project
# 1521  2019            nl     Netherlands             Duncan Laurence
# 1439  2017            be         Belgium                     Blanche
# 1479  2018            cy          Cyprus              Eleni Foureira
# 1522  2019            it           Italy                     Mahmood
# 1482  2018            it           Italy  Ermal Meta & Fabrizio Moro
# 1523  2019            ru          Russia              Sergey Lazarev
# ...

# %%
df1.sort_values("points_tele_final", ascending = False, inplace = True)
#df1 = df1[df1["round"]=="final"]
#df1 = df1[df1["to_country"]=="France"]
#df1 = df1[~(df1['round'] == "semi")] 
#df1 = df1[~(df1['jury_points'] == 0.0)]

# %%
df1.head()
# Out:
#       year to_country_id to_country        performer                  song  \
# 1436  2017            pt   Portugal  Salvador Sobral       Amar Pelos Dois
# 1396  2016            ru     Russia   Sergey Lazarev  You Are the Only One
# 1437  2017            bg   Bulgaria  Kristian Kostov        Beautiful Mess
# 1394  2016            ua    Ukraine           Jamala                  1944
# 1478  2018            il     Israel   Netta Barzilai                   Toy
#
#       place_contest  sf_num  running_final  running_sf  place_final  ...  \
# 1436            1.0     1.0           11.0         9.0          1.0  ...
# 1396            3.0     1.0           18.0         9.0          3.0  ...
# 1437            2.0     2.0           25.0        15.0          2.0  ...
# 1394            1.0     2.0           21.0        14.0          1.0  ...
# 1478            1.0     1.0           22.0         7.0          1.0  ...
#
#       place_sf  points_sf  points_tele_final  points_jury_final  \
# ...
