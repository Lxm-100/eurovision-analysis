# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Formatting the votes.csv file

# %%
votes = pd.read_csv("../data/votes.csv")

# %% [markdown]
# ### boolean masks to create a subset
#
# votes.sort_values("year", ascending = False, inplace = True)
# votes = votes[votes["round"]=="final"]
# votes = votes[votes["from_country_id"]=="fr"]
# votes = votes[~(votes['round'] == "semi")]
# votes = votes[~(votes['jury_points'] == 0.0)]

# %%
votes.tail()
# Out:
#        year  round from_country_id to_country_id    from_country to_country  \
# 49979  2023  final             NaN           NaN           SPAIN    GERMANY
# 49980  2023  final             NaN           NaN          SWEDEN    GERMANY
# 49981  2023  final             NaN           NaN     SWITZERLAND    GERMANY
# 49982  2023  final             NaN           NaN         UKRAINE    GERMANY
# 49983  2023  final             NaN           NaN  UNITED KINGDOM    GERMANY
#
#        total_points  tele_points  jury_points
# 49979             0          NaN            0
# 49980             0          NaN            0
# 49981             0          NaN            0
# 49982             0          NaN            0
# 49983             0          NaN            0

# %%
votes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49984 entries, 0 to 49983
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             49984 non-null  int64
#  1   round            49984 non-null  object
#  2   from_country_id  47815 non-null  object
#  3   to_country_id    47018 non-null  object
#  4   from_country     49984 non-null  object
#  5   to_country       49984 non-null  object
#  6   total_points     49984 non-null  int64
#  7   tele_points      7518 non-null   float64
#  8   jury_points      49984 non-null  int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 3.4+ MB

# %% [markdown]
# # Formatting the contestants.csv file

# %%
contestants = pd.read_csv("../data/contestants.csv")

# %%
contestants.head()
# Out:
#    year to_country_id   to_country               performer  \
# 0  1956            ch  Switzerland               Lys Assia
# 1  1956            nl  Netherlands             Jetty Paerl
# 2  1956            be      Belgium             Fud Leclerc
# 3  1956            de      Germany  Walter Andreas Schwarz
# 4  1956            fr       France            Mathé Altéry
#
#                               song  place_contest  sf_num  running_final  \
# 0                          Refrain              2     NaN            2.0
# 1            De Vogels Van Holland              2     NaN            1.0
# 2  Messieurs Les Noyés De La Seine              2     NaN            3.0
# 3    Im Wartesaal Zum Großen Glück              2     NaN            4.0
# 4                   Le Temps Perdu              2     NaN            5.0
#
#    running_sf  place_final  ...                              Unnamed: 21  \
# 0         NaN          2.0  ...                                      NaN
# ...

# %%
contestants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1562 entries, 0 to 1561
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               1562 non-null   int64
#  1   to_country_id      1562 non-null   object
#  2   to_country         1562 non-null   object
#  3   performer          1562 non-null   object
#  4   song               1559 non-null   object
#  5   place_contest      1562 non-null   int64
#  6   sf_num             522 non-null    float64
#  7   running_final      1320 non-null   float64
#  8   running_sf         522 non-null    float64
#  9   place_final        1320 non-null   float64
#  10  points_final       1309 non-null   float64
#  11  place_sf           522 non-null    float64
#  12  points_sf          522 non-null    float64
#  13  points_tele_final  104 non-null    float64
#  14  points_jury_final  104 non-null    float64
# ...

# %% [markdown]
# ### Boolean masks to create a subset
#
# df1.sort_values("points_tele_final", ascending = False, inplace = True)
# #df1 = df1[df1["round"]=="final"]
# #df1 = df1[df1["to_country"]=="France"]
# #df1 = df1[~(df1['round'] == "semi")]
# #df1 = df1[~(df1['jury_points'] == 0.0)]

# %%
contestants["place_contest"].astype(np.int64)
# Out:
# 0        2
# 1        2
# 2        2
# 3        2
# 4        2
#         ..
# 1557    37
# 1558    38
# 1559    39
# 1560    40
# 1561    41
# Name: place_contest, Length: 1562, dtype: int64

# %%
contestants.isnull().sum(axis = 0)
# Out:
# year                    0
# to_country_id           0
# to_country              0
# performer               0
# song                    3
# place_contest           0
# sf_num               1040
# running_final         242
# running_sf           1040
# place_final           242
# points_final          253
# place_sf             1040
# points_sf            1040
# points_tele_final    1458
# points_jury_final    1458
# points_tele_sf       1418
# points_jury_sf       1418
# composers               1
# lyricists             370
# lyrics                120
# youtube_url            81
# Unnamed: 21           997
# Unnamed: 22          1298
# Unnamed: 23          1451
# Unnamed: 24          1517
# Unnamed: 25          1542
# Unnamed: 26          1557
# Unnamed: 27          1557
# Unnamed: 28          1561
# Unnamed: 29          1560
# Unnamed: 30          1561
# dtype: int64

# %% [markdown]
# ## Drop all columns that are not needed (semi-final stuff)

# %%
#contestants.drop(['sf_num', 'running_sf', "place_sf", "points_tele_sf", "points_jury_sf", "composers", "lyricists"], 
                 axis = 1, inplace = True)

# %%
#contestants.drop(['points_sf',"Unnamed: 21", "Unnamed: 22", "Unnamed: 23", "Unnamed: 24", "Unnamed: 25", "Unnamed: 26", "Unnamed: 26",
                 "Unnamed: 27", "Unnamed: 28", "Unnamed: 29", "Unnamed: 30"], 
                 axis = 1, inplace = True)

# %%
contestants.isnull().sum(axis = 0)
# Out:
# year                    0
# to_country_id           0
# to_country              0
# performer               0
# song                    3
# place_contest           0
# running_final         242
# place_final           242
# points_final          253
# points_tele_final    1458
# points_jury_final    1458
# lyrics                120
# youtube_url            81
# dtype: int64

# %%
contestants.head()
# Out:
#    year to_country_id   to_country               performer  \
# 0  1956            ch  Switzerland               Lys Assia
# 1  1956            nl  Netherlands             Jetty Paerl
# 2  1956            be      Belgium             Fud Leclerc
# 3  1956            de      Germany  Walter Andreas Schwarz
# 4  1956            fr       France            Mathé Altéry
#
#                               song  place_contest  running_final  place_final  \
# 0                          Refrain              2            2.0          2.0
# 1            De Vogels Van Holland              2            1.0          2.0
# 2  Messieurs Les Noyés De La Seine              2            3.0          2.0
# 3    Im Wartesaal Zum Großen Glück              2            4.0          2.0
# 4                   Le Temps Perdu              2            5.0          2.0
#
#    points_final  points_tele_final  points_jury_final  \
# 0           0.0                NaN                NaN
# ...

# %%
#contestants.to_csv('../data/contestants_clean.csv', index=False)

# %%
#contestants_clean = pd.read_csv("../data/contestants_clean2.csv")

# contestants_clean2.csv has all semi-final related information cleaned

# %%
contestants_clean.head()
# Out:
#    year to_country_id   to_country                       performer  \
# 0  1957            nl  Netherlands                   Corry Brokken
# 1  1957            fr       France                Paule Desjardins
# 2  1957            dk      Denmark  Birthe Wilke & Gustav Winckler
# 3  1957            lu   Luxembourg                   Danièle Dupré
# 4  1957            de      Germany                Margot Hielscher
#
#                             song  place_contest  running_final  place_final  \
# 0                   Net Als Toen              1              6            1
# 1                 La Belle Amour              2              8            2
# 2        Skibet Skal Sejle I Nat              3              9            3
# 3  Amours Mortes (Tant De Peine)              4              2            4
# 4               Telefon, Telefon              4              7            4
#
#    points_final  points_tele_final  points_jury_final  \
# ...

# %%
contestants_clean.isnull().sum(axis = 0)
# Out:
# year                   0
# to_country_id          0
# to_country             0
# performer              0
# song                   0
# place_contest          0
# running_final          0
# place_final            0
# points_final           0
# points_tele_final      0
# points_jury_final      0
# lyrics               101
# youtube_url           65
# dtype: int64

# %% [markdown]
# ## Change final float64 to int64 type

# %%
contestants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1562 entries, 0 to 1561
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               1562 non-null   int64
#  1   to_country_id      1562 non-null   object
#  2   to_country         1562 non-null   object
#  3   performer          1562 non-null   object
#  4   song               1559 non-null   object
#  5   place_contest      1562 non-null   int64
#  6   running_final      1320 non-null   float64
#  7   place_final        1320 non-null   float64
#  8   points_final       1309 non-null   float64
#  9   points_tele_final  104 non-null    float64
#  10  points_jury_final  104 non-null    float64
#  11  lyrics             1442 non-null   object
#  12  youtube_url        1481 non-null   object
# dtypes: float64(5), int64(2), object(6)
# memory usage: 158.8+ KB

# %%
contestants_clean["running_final"].astype(np.int64)
# Out:
# 0        6
# 1        8
# 2        9
# 3        2
# 4        7
#         ..
# 1303    26
# 1304    14
# 1305    19
# 1306     4
# 1307    16
# Name: running_final, Length: 1308, dtype: int64

# %%
contestants_clean["place_final"].astype(np.int64)
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        4
#         ..
# 1303    22
# 1304    23
# 1305    24
# 1306    25
# 1307    26
# Name: place_final, Length: 1308, dtype: int64

# %%
contestants_clean["points_tele_final"].astype(np.int64)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 1303    53
# 1304    35
# 1305    13
# 1306     0
# 1307     3
# Name: points_tele_final, Length: 1308, dtype: int64

# %%
contestants_clean["points_jury_final"].astype(np.int64)
# Out:
# 0       31
# 1       17
# 2       10
# 3        8
# 4        8
#         ..
# 1303     1
# 1304     0
# 1305    18
# 1306    24
# 1307     8
# Name: points_jury_final, Length: 1308, dtype: int64

# %%
contestants_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308 entries, 0 to 1307
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               1308 non-null   int64
#  1   to_country_id      1308 non-null   object
#  2   to_country         1308 non-null   object
#  3   performer          1308 non-null   object
#  4   song               1308 non-null   object
#  5   place_contest      1308 non-null   int64
#  6   running_final      1308 non-null   int64
#  7   place_final        1308 non-null   int64
#  8   points_final       1308 non-null   int64
#  9   points_tele_final  1308 non-null   int64
#  10  points_jury_final  1308 non-null   int64
#  11  lyrics             1207 non-null   object
#  12  youtube_url        1243 non-null   object
# dtypes: int64(7), object(6)
# memory usage: 133.0+ KB

# %%
contestants_clean.head()
# Out:
#    year to_country_id   to_country                       performer  \
# 0  1957            nl  Netherlands                   Corry Brokken
# 1  1957            fr       France                Paule Desjardins
# 2  1957            dk      Denmark  Birthe Wilke & Gustav Winckler
# 3  1957            lu   Luxembourg                   Danièle Dupré
# 4  1957            de      Germany                Margot Hielscher
#
#                             song  place_contest  running_final  place_final  \
# 0                   Net Als Toen              1              6            1
# 1                 La Belle Amour              2              8            2
# 2        Skibet Skal Sejle I Nat              3              9            3
# 3  Amours Mortes (Tant De Peine)              4              2            4
# 4               Telefon, Telefon              4              7            4
#
#    points_final  points_tele_final  points_jury_final  \
# ...

# %% [markdown]
# ### Export finalized cleaned file again

# %%
#contestants_clean.to_csv('../data/contestants_clean2.csv', index=False)

# %% [markdown]
# ### Manually added data from 2021-2023 and read data frame again

# %%
contestants_clean_fin = pd.read_csv("../data/contestants_clean2.csv")

# %% [markdown]
# ### Adding 1.st of May date to all ESC dates
#
# - otherwise overlay of political events will not show up correctly in relation to the contest dates

# %%
contestants_clean_fin["year"] = contestants_clean_fin["year"].astype(str)

# %%
contestants_clean_fin["year"] = contestants_clean_fin["year"].astype(str) + "-05-01"

# %%
contestants_clean_fin['year'] = pd.to_datetime(contestants_clean_fin['year'], format='%Y-%m-%d %H:%M:%S')

# %%
contestants_clean_fin.head(2)
# Out:
#         year to_country_id   to_country         performer            song  \
# 0 1957-05-01            nl  Netherlands     Corry Brokken    Net Als Toen
# 1 1957-05-01            fr       France  Paule Desjardins  La Belle Amour
#
#    place_contest  running_final  place_final  points_final  points_tele_final  \
# 0              1              6            1            31                  0
# 1              2              8            2            17                  0
#
#    points_jury_final                                             lyrics  \
# 0                 31  Zit niet zo suf met die eeuwige krant\nGaap ni...
# 1                 17  Si vous aimez la nature, les lilas, les p'tits...
#
#                                youtube_url
# 0  https://youtube.com/watch?v=e5gLyP977ew
# 1  https://youtube.com/watch?v=g2-XDnBHEbc

# %%
contestants_clean_fin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1385 entries, 0 to 1384
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   year               1385 non-null   datetime64[ns]
#  1   to_country_id      1308 non-null   object
#  2   to_country         1385 non-null   object
#  3   performer          1308 non-null   object
#  4   song               1308 non-null   object
#  5   place_contest      1385 non-null   int64
#  6   running_final      1385 non-null   int64
#  7   place_final        1385 non-null   int64
#  8   points_final       1385 non-null   int64
#  9   points_tele_final  1385 non-null   int64
#  10  points_jury_final  1385 non-null   int64
#  11  lyrics             1207 non-null   object
#  12  youtube_url        1243 non-null   object
# dtypes: datetime64[ns](1), int64(6), object(6)
# memory usage: 140.8+ KB

# %%
#contestants_clean_fin.to_csv('../data/contestants_clean2.csv', index=False)

# %% [markdown]
# # Add country codes to votes.csv file

# %%
votes.tail()
# Out:
#        year  round from_country_id to_country_id    from_country to_country  \
# 49979  2023  final             NaN           NaN           SPAIN    GERMANY
# 49980  2023  final             NaN           NaN          SWEDEN    GERMANY
# 49981  2023  final             NaN           NaN     SWITZERLAND    GERMANY
# 49982  2023  final             NaN           NaN         UKRAINE    GERMANY
# 49983  2023  final             NaN           NaN  UNITED KINGDOM    GERMANY
#
#        total_points  tele_points  jury_points
# 49979             0          NaN            0
# 49980             0          NaN            0
# 49981             0          NaN            0
# 49982             0          NaN            0
# 49983             0          NaN            0

# %%
country_codes = pd.read_csv("../data/country_codes.csv")

# %%
country_codes.head()
# Out:
#              name alpha2 alpha3
# 0     Afghanistan     AF    AFG
# 1         Albania     AL    ALB
# 2         Algeria     DZ    DZA
# 3  American Samoa     AS    ASM
# 4         Andorra     AD    AND

# %%
country_codes["name"] = country_codes["name"].str.upper()

# %%
country_codes.rename(columns={'name': 'from_country'},
          inplace=True, errors='raise')

# %%
country_codes.head()
# Out:
#      from_country alpha2 alpha3
# 0     AFGHANISTAN     AF    AFG
# 1         ALBANIA     AL    ALB
# 2         ALGERIA     DZ    DZA
# 3  AMERICAN SAMOA     AS    ASM
# 4         ANDORRA     AD    AND

# %%
df_test = votes.merge(country_codes, on="from_country", how="left", indicator=True)

# %%
df_test.tail()
# Out:
#        year  round from_country_id to_country_id    from_country to_country  \
# 49979  2023  final             NaN           NaN           SPAIN    GERMANY
# 49980  2023  final             NaN           NaN          SWEDEN    GERMANY
# 49981  2023  final             NaN           NaN     SWITZERLAND    GERMANY
# 49982  2023  final             NaN           NaN         UKRAINE    GERMANY
# 49983  2023  final             NaN           NaN  UNITED KINGDOM    GERMANY
#
#        total_points  tele_points  jury_points alpha2 alpha3 _merge
# 49979             0          NaN            0     ES    ESP   both
# 49980             0          NaN            0     SE    SWE   both
# 49981             0          NaN            0     CH    CHE   both
# 49982             0          NaN            0     UA    UKR   both
# 49983             0          NaN            0     GB    GBR   both

# %%
df_test.sort_values(by=["_merge"], inplace = True)

# %%
df_test.head()
# Out:
#        year  round from_country_id to_country_id from_country  \
# 0      1957  final              at            nl      AUSTRIA
# 33317  2012  final              il            es       ISRAEL
# 33318  2012  final              il            md       ISRAEL
# 33319  2012  final              il            ro       ISRAEL
# 33320  2012  final              il            mk       ISRAEL
#
#             to_country  total_points  tele_points  jury_points alpha2 alpha3  \
# 0          NETHERLANDS             6          NaN            6     AT    AUT
# 33317            SPAIN            10          NaN           10     IL    ISR
# 33318          MOLDOVA             5          NaN            5     IL    ISR
# 33319          ROMANIA             6          NaN            6     IL    ISR
# 33320  NORTH MACEDONIA             0          NaN            0     IL    ISR
#
#       _merge
# 0       both
# 33317   both
# 33318   both
# 33319   both
# 33320   both

# %%
df_test.drop(['alpha2', 'alpha3', "_merge"], axis = 1, inplace = True)

# %%
votes_clean = df_test

# %% [markdown]
# ### Adding 1.st of May date to all ESC dates
#
# - otherwise overlay of political events will not show up correctly in relation to the contest dates

# %%
#votes_clean = pd.read_csv("../data/votes_clean.csv")

# %%
votes_clean["year"] = votes_clean["year"].astype(str)

# %%
votes_clean["year"] = votes_clean["year"].astype(str) + "-05-01"

# %%
votes_clean['year'] = pd.to_datetime(votes_clean['year'], format='%Y-%m-%d %H:%M:%S')

# %%
votes_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49984 entries, 0 to 49983
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             49984 non-null  datetime64[ns]
#  1   round            49984 non-null  object
#  2   from_country_id  47815 non-null  object
#  3   to_country_id    47018 non-null  object
#  4   from_country     49984 non-null  object
#  5   to_country       49984 non-null  object
#  6   total_points     49984 non-null  int64
#  7   tele_points      7518 non-null   float64
#  8   jury_points      49984 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(5)
# memory usage: 3.4+ MB

# %%
votes_clean.head(10)
# Out:
#         year  round from_country_id to_country_id from_country  \
# 0 1957-05-01  final              at            nl      AUSTRIA
# 1 2012-05-01  final              il            es       ISRAEL
# 2 2012-05-01  final              il            md       ISRAEL
# 3 2012-05-01  final              il            ro       ISRAEL
# 4 2012-05-01  final              il            mk       ISRAEL
# 5 2012-05-01  final              il            lt       ISRAEL
# 6 2012-05-01  final              il            ua       ISRAEL
# 7 2012-05-01  final              il            cy       ISRAEL
# 8 2012-05-01  final              il            gr       ISRAEL
# 9 2012-05-01  final              il            ba       ISRAEL
#
#                to_country  total_points  tele_points  jury_points
# 0             NETHERLANDS             6          NaN            6
# 1                   SPAIN            10          NaN           10
# 2                 MOLDOVA             5          NaN            5
# ...

# %%
votes_clean = votes_clean.sort_values(by=['year', "to_country"], ascending=True)

# %%
#votes_clean.to_csv('../data/votes_clean.csv', index=False)

# %%
#votes_clean = pd.read_csv("../data/votes_clean.csv")

# %%
votes_clean.head()
# Out:
#          year  round from_country_id to_country_id from_country   to_country  \
# 0  1957-05-01  final              at            nl      AUSTRIA  NETHERLANDS
# 1  1957-05-01  final              at            fr      AUSTRIA       FRANCE
# 2  1957-05-01  final              at            dk      AUSTRIA      DENMARK
# 3  1957-05-01  final              at            lu      AUSTRIA   LUXEMBOURG
# 4  1957-05-01  final              at            de      AUSTRIA      GERMANY
#
#    total_points  tele_points  jury_points
# 0             6          NaN            6
# 1             0          NaN            0
# 2             0          NaN            0
# 3             3          NaN            3
# 4             0          NaN            0

# %%
votes_test = votes_clean.merge(country_codes, on="from_country", how="left", indicator=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 votes_test = votes_clean.merge(country_codes, on="to_country", how="left", indicator=True)
#
# File c:\python38\lib\site-packages\pandas\core\frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# > 10093     return merge(
#   10094         self,
#   10095         right,
#   10096         how=how,
#   10097         on=on,
#   10098         left_on=left_on,
#   10099         right_on=right_on,
#   10100         left_index=left_index,
#   10101         right_index=right_index,
# ...

# %%
votes_test.sort_values(by=["_merge"], inplace = True)

# %%
votes_test.drop(['alpha2', 'alpha3', "_merge"], axis = 1, inplace = True)

# %%
votes_test.head()
# Out:
#              year  round from_country_id to_country_id from_country  \
# 0      1957-05-01  final              at            nl      AUSTRIA
# 33317  2012-05-01  final              ro            es      ROMANIA
# 33318  2012-05-01  final              ro            md      ROMANIA
# 33319  2012-05-01  final              ro            ro      ROMANIA
# 33320  2012-05-01  final              ru            al       RUSSIA
#
#         to_country  total_points  tele_points  jury_points
# 0      NETHERLANDS             6          NaN            6
# 33317        SPAIN             6          NaN            6
# 33318      MOLDOVA            12          NaN           12
# 33319      ROMANIA             0          NaN            0
# 33320      ALBANIA             0          NaN            0

# %%
votes_clean = votes_test
